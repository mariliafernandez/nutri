# %%
import pandas as pd

# %%
df = pd.read_json('raw_data.json', orient='records')

# %%
df
# Out:
#       id              description             category humidity_percents  \
# 0      1  Arroz, integral, cozido  Cereais e derivados         70.138667
# 1      2     Arroz, integral, cru  Cereais e derivados         12.179833
# 2      3    Arroz, tipo 1, cozido  Cereais e derivados         69.113667
# 3      4       Arroz, tipo 1, cru  Cereais e derivados           13.2245
# 4      5    Arroz, tipo 2, cozido  Cereais e derivados         68.727667
# ..   ...                      ...                  ...               ...
# 592  593        Gergelim, semente     Nozes e sementes          3.859333
# 593  594         Linhaça, semente     Nozes e sementes             6.683
# 594  595           Pinhão, cozido     Nozes e sementes         50.513333
# 595  596          Pupunha, cozida     Nozes e sementes             54.46
# 596  597                Noz, crua     Nozes e sementes          6.244667
#
#      energy_kcal    energy_kj  protein_g    lipid_g cholesterol_mg  \
# 0     123.534892   516.869990    2.58825   1.000333             NA
# 1     359.678002  1504.892761   7.323286   1.864833             NA
# 2     128.258486   536.633504   2.520817      0.227             NA
# 3     357.789273  1496.990319    7.15854      0.335             NA
# 4     130.119648   544.420609   2.568417   0.361667             NA
# ..           ...          ...        ...        ...            ...
# 592   583.546715  2441.559455  21.164667  50.432667             NA
# 593   495.096114  2071.534915  14.083867  32.252933             NA
# 594   174.369902   729.563670   2.980367      0.747             NA
# 595   218.533881   914.345758   2.522917  12.761667             NA
# 596   620.060020  2594.331123  13.970801  59.359667             NA
#
#     carbohydrate_g  ... tyrosine_g valine_g arginine_g histidine_g alanine_g  \
# 0         25.80975  ...
# 1        77.450714  ...
# 2         28.05985  ...
# 3        78.759543  ...
# 4        28.192583  ...
# ..             ...  ...        ...      ...        ...         ...       ...
# 592      21.617666  ...
# 593      43.312199  ...
# 594      43.917633  ...
# 595      29.569417  ...
# 596      18.363866  ...
#
#     aspartic_g glutamic_g glycine_g proline_g serine_g
# 0
# 1
# 2
# 3
# 4
# ..         ...        ...       ...       ...      ...
# 592
# 593
# 594
# 595
# 596
#
# [597 rows x 69 columns]

# %%
df['energy_kcal'].replace('Tr', -1, inplace=True)
df['protein_g'].replace('Tr', -1, inplace=True)
df['lipid_g'].replace('Tr', -1, inplace=True)
df['carbohydrate_g'].replace('Tr', -1, inplace=True)
df['fiber_g'].replace('Tr', -1, inplace=True)

df['energy_kcal'].replace('NA', -1, inplace=True)
df['protein_g'].replace('NA', -1, inplace=True)
df['lipid_g'].replace('NA', -1, inplace=True)
df['carbohydrate_g'].replace('NA', -1, inplace=True)
df['fiber_g'].replace('NA', -1, inplace=True)

df['energy_kcal'].replace('*', -1, inplace=True)
df['protein_g'].replace('*', -1, inplace=True)
df['lipid_g'].replace('*', -1, inplace=True)
df['carbohydrate_g'].replace('*', -1, inplace=True)
df['fiber_g'].replace('*', -1, inplace=True)

df['energy_kcal'].replace('', -1, inplace=True)
df['protein_g'].replace('', -1, inplace=True)
df['lipid_g'].replace('', -1, inplace=True)
df['carbohydrate_g'].replace('', -1, inplace=True)
df['fiber_g'].replace('', -1, inplace=True)
# Out:
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\2803559847.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['energy_kcal'].replace('Tr', -1, inplace=True)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\2803559847.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['protein_g'].replace('Tr', -1, inplace=True)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\2803559847.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['lipid_g'].replace('Tr', -1, inplace=True)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\2803559847.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['carbohydrate_g'].replace('Tr', -1, inplace=True)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\2803559847.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['fiber_g'].replace('Tr', -1, inplace=True)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\2803559847.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['energy_kcal'].replace('NA', -1, inplace=True)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\2803559847.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['protein_g'].replace('NA', -1, inplace=True)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\2803559847.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['lipid_g'].replace('NA', -1, inplace=True)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\2803559847.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['carbohydrate_g'].replace('NA', -1, inplace=True)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\2803559847.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['fiber_g'].replace('NA', -1, inplace=True)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\2803559847.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['energy_kcal'].replace('*', -1, inplace=True)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\2803559847.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['protein_g'].replace('*', -1, inplace=True)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\2803559847.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['lipid_g'].replace('*', -1, inplace=True)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\2803559847.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['carbohydrate_g'].replace('*', -1, inplace=True)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\2803559847.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['fiber_g'].replace('*', -1, inplace=True)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\2803559847.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['energy_kcal'].replace('', -1, inplace=True)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\2803559847.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['protein_g'].replace('', -1, inplace=True)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\2803559847.py:20: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['protein_g'].replace('', -1, inplace=True)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\2803559847.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['lipid_g'].replace('', -1, inplace=True)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\2803559847.py:21: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['lipid_g'].replace('', -1, inplace=True)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\2803559847.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['carbohydrate_g'].replace('', -1, inplace=True)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\2803559847.py:22: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['carbohydrate_g'].replace('', -1, inplace=True)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\2803559847.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['fiber_g'].replace('', -1, inplace=True)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\2803559847.py:23: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['fiber_g'].replace('', -1, inplace=True)

# %%
df.loc[:,'id'] = df['id'].astype(int)
df.loc[:,'description'] = df['description'].astype(str)
df.loc[:,'category'] = df['category'].astype(str)
df.loc[:,'energy_kcal'] = df['energy_kcal'].astype(float)
df.loc[:,'protein_g'] = df['protein_g'].astype(float)
df.loc[:,'lipid_g'] = df['lipid_g'].astype(float)
df.loc[:,'carbohydrate_g'] = df['carbohydrate_g'].astype(float)
df.loc[:,'fiber_g'] = df['fiber_g'].astype(float)

# %%
df['energy_kcal'].replace(-1, None, inplace=True)
df['protein_g'].replace(-1, None, inplace=True)
df['lipid_g'].replace(-1, None, inplace=True)
df['carbohydrate_g'].replace(-1, None, inplace=True)
df['fiber_g'].replace(-1, None, inplace=True)
# Out:
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\1295830741.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['energy_kcal'].replace(-1, None, inplace=True)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\1295830741.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['protein_g'].replace(-1, None, inplace=True)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\1295830741.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['lipid_g'].replace(-1, None, inplace=True)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\1295830741.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['carbohydrate_g'].replace(-1, None, inplace=True)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_9472\1295830741.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['fiber_g'].replace(-1, None, inplace=True)

# %%
df['splitted'] = df['description'].apply(lambda x: [s.strip() for s in x.split(',')])

# %%
columns = ['id', 'description', 'category', 'splitted', 'energy_kcal', 'protein_g', 'lipid_g', 'carbohydrate_g','fiber_g']
df[columns]
# Out:
#       id              description             category  \
# 0      1  Arroz, integral, cozido  Cereais e derivados
# 1      2     Arroz, integral, cru  Cereais e derivados
# 2      3    Arroz, tipo 1, cozido  Cereais e derivados
# 3      4       Arroz, tipo 1, cru  Cereais e derivados
# 4      5    Arroz, tipo 2, cozido  Cereais e derivados
# ..   ...                      ...                  ...
# 592  593        Gergelim, semente     Nozes e sementes
# 593  594         Linhaça, semente     Nozes e sementes
# 594  595           Pinhão, cozido     Nozes e sementes
# 595  596          Pupunha, cozida     Nozes e sementes
# 596  597                Noz, crua     Nozes e sementes
#
#                       splitted  energy_kcal  protein_g    lipid_g  \
# 0    [Arroz, integral, cozido]   123.534892    2.58825   1.000333
# 1       [Arroz, integral, cru]   359.678002   7.323286   1.864833
# 2      [Arroz, tipo 1, cozido]   128.258486   2.520817      0.227
# 3         [Arroz, tipo 1, cru]   357.789273    7.15854      0.335
# 4      [Arroz, tipo 2, cozido]   130.119648   2.568417   0.361667
# ..                         ...          ...        ...        ...
# 592        [Gergelim, semente]   583.546715  21.164667  50.432667
# 593         [Linhaça, semente]   495.096114  14.083867  32.252933
# 594           [Pinhão, cozido]   174.369902   2.980367      0.747
# 595          [Pupunha, cozida]   218.533881   2.522917  12.761667
# 596                [Noz, crua]   620.060020  13.970801  59.359667
#
#     carbohydrate_g    fiber_g
# 0         25.80975   2.749333
# 1        77.450714   4.819167
# 2         28.05985      1.561
# 3        78.759543   1.639167
# 4        28.192583   1.069667
# ..             ...        ...
# 592      21.617666  11.868333
# 593      43.312199  33.502667
# 594      43.917633  15.603333
# 595      29.569417   4.253333
# 596      18.363866   7.249667
#
# [597 rows x 9 columns]

# %%
df[columns].to_json('taco.json', orient='records', indent=4, index=False, force_ascii=False)
