# %% [markdown]
# * Tabela oficial: https://www.nepa.unicamp.br/wp-content/uploads/sites/27/2023/10/Taco-4a-Edicao.xlsx
# * JSON: https://github.com/marcelosanto/tabela_taco

# %%
path = r"tab01.xls"

# %%
import pandas as pd
df = pd.read_excel(path)
df.head()
# Out:
#   Tabela 1 - Energia, macronutrientes e fibra na composição de alimentos por 100 gramas de parte comestível  \
# 0                                                NaN
# 1                                                NaN
# 2                    Código e descrição do alimento
# 3                              Cereais e leguminosas
# 4                                            6300101
#
#                                           Unnamed: 1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Arroz (polido, parboilizado, agulha, agulhinha...
#
#                          Unnamed: 2     Unnamed: 3      Unnamed: 4  \
# 0                               NaN            NaN             NaN
# 1                               NaN            NaN             NaN
# 2  Código e descrição da preparação            NaN  Energia (kcal)
# 3                               NaN            NaN             NaN
# 4                                99  Não se aplica      135.622946
#
#       Unnamed: 5            Unnamed: 6           Unnamed: 7  \
# 0            NaN                   NaN                  NaN
# 1            NaN                   NaN                  NaN
# 2  Proteína\n(g)  Lipídios totais\n(g)  Carboi-\ndrato\n(g)
# 3            NaN                   NaN                  NaN
# 4       2.496113              1.200042            27.784863
#
#                   Unnamed: 8
# 0                        NaN
# 1              (continuação)
# 2  Fibra alimentar total (g)
# 3                        NaN
# 4                   1.545702

# %%
column_names = ['food_id', 'food_description', 'cooking_method_id', 'cooking_method_description', 'energy_kcal', 'protein_g', 'lipid_g', 'carbohydrate_g','fiber_g']
df.columns = column_names
df = df[3:]

# %%
df
# Out:
#                                                 food_id  \
# 3                                 Cereais e leguminosas
# 4                                               6300101
# 5                                               6300201
# 6                                               6300701
# 7                                               6300701
# ...                                                 ...
# 1992                                            8800109
# 1993                                                NaN
# 1994  Fonte: IBGE, Diretoria de Pesquisas, Coordenaç...
# 1995  Notas: 1. Células com valores igual a "0,00" r...
# 1996              2. Células com "-" (traço) represe...
#
#                                        food_description cooking_method_id  \
# 3                                                   NaN               NaN
# 4     Arroz (polido, parboilizado, agulha, agulhinha...                99
# 5                                        Arroz integral                99
# 6                                       Milho (em grão)                 1
# 7                                       Milho (em grão)                 2
# ...                                                 ...               ...
# 1992                                             Palma                 99
# 1993                                                NaN               NaN
# 1994                                                NaN               NaN
# 1995                                                NaN               NaN
# 1996                                                NaN               NaN
#
#      cooking_method_description energy_kcal protein_g   lipid_g  \
# 3                           NaN         NaN       NaN       NaN
# 4                 Não se aplica  135.622946  2.496113  1.200042
# 5                 Não se aplica  130.945644  2.562885  1.965797
# 6                        Cru(a)     160.141      3.32     7.178
# 7                     Cozido(a)     160.141      3.32     7.178
# ...                         ...         ...       ...       ...
# 1992              Não se aplica      41.945      1.35     3.098
# 1993                        NaN         NaN       NaN       NaN
# 1994                        NaN         NaN       NaN       NaN
# 1995                        NaN         NaN       NaN       NaN
# 1996                        NaN         NaN       NaN       NaN
#
#      carbohydrate_g   fiber_g
# 3               NaN       NaN
# 4         27.784863  1.545702
# 5         25.556814   2.72239
# 6             25.11      4.25
# 7             25.11      4.25
# ...             ...       ...
# 1992           3.28         2
# 1993            NaN       NaN
# 1994            NaN       NaN
# 1995            NaN       NaN
# 1996            NaN       NaN
#
# [1994 rows x 9 columns]

# %%
df.loc[df[column_names[1:]].isnull().any(axis=1), 'food_id'].to_list()
# Out:
# ['Cereais e leguminosas',
#  'Hortaliças tuberosas',
#  'Farinhas, féculas e massas',
#  'Cocos, castanhas e nozes',
#  'Hortaliças folhosas, frutosas e outras',
#  'Frutas',
#  'Açúcares e produtos de confeitaria ',
#  'Sais e condimentos',
#  'Carnes e vísceras',
#  'Pescados e frutos do mar',
#  'Enlatados e conservas',
#  'Aves e ovos  ',
#  'Laticínios',
#  'Panificados',
#  'Carnes industrializadas',
#  'Bebidas não alcoólicas e infusões',
#  'Bebidas alcoólicas',
#  'Óleos e gorduras',
#  'Miscelâneas',
#  nan,
#  'Fonte: IBGE, Diretoria de Pesquisas, Coordenação de Trabalho e Rendimento, Pesquisa de Orçamentos Familiares 2008-2009.',
#  'Notas: 1. Células com valores igual a "0,00" representam valores abaixo dos limites de quantificação.',
#  '            2. Células com "-" (traço) representam valores nutricionais ausentes ou não disponíveis.']

# %%
categorias = df.loc[df[column_names[1:]].isnull().any(axis=1), 'food_id'].to_list()
categorias
# Out:
# ['Cereais e leguminosas',
#  'Hortaliças tuberosas',
#  'Farinhas, féculas e massas',
#  'Cocos, castanhas e nozes',
#  'Hortaliças folhosas, frutosas e outras',
#  'Frutas',
#  'Açúcares e produtos de confeitaria ',
#  'Sais e condimentos',
#  'Carnes e vísceras',
#  'Pescados e frutos do mar',
#  'Enlatados e conservas',
#  'Aves e ovos  ',
#  'Laticínios',
#  'Panificados',
#  'Carnes industrializadas',
#  'Bebidas não alcoólicas e infusões',
#  'Bebidas alcoólicas',
#  'Óleos e gorduras',
#  'Miscelâneas',
#  nan,
#  'Fonte: IBGE, Diretoria de Pesquisas, Coordenação de Trabalho e Rendimento, Pesquisa de Orçamentos Familiares 2008-2009.',
#  'Notas: 1. Células com valores igual a "0,00" representam valores abaixo dos limites de quantificação.',
#  '            2. Células com "-" (traço) representam valores nutricionais ausentes ou não disponíveis.']

# %%
df['category'] = None
df.loc[df[column_names[1:]].isnull().any(axis=1), 'category'] = categorias

# %%
df['category'].ffill()
# Out:
# 3                                   Cereais e leguminosas
# 4                                   Cereais e leguminosas
# 5                                   Cereais e leguminosas
# 6                                   Cereais e leguminosas
# 7                                   Cereais e leguminosas
#                               ...
# 1992                                          Miscelâneas
# 1993                                          Miscelâneas
# 1994    Fonte: IBGE, Diretoria de Pesquisas, Coordenaç...
# 1995    Notas: 1. Células com valores igual a "0,00" r...
# 1996                2. Células com "-" (traço) represe...
# Name: category, Length: 1994, dtype: object

# %%
df['category'] = df['category'].ffill()

# %%
df
# Out:
#                                                 food_id  \
# 3                                 Cereais e leguminosas
# 4                                               6300101
# 5                                               6300201
# 6                                               6300701
# 7                                               6300701
# ...                                                 ...
# 1992                                            8800109
# 1993                                                NaN
# 1994  Fonte: IBGE, Diretoria de Pesquisas, Coordenaç...
# 1995  Notas: 1. Células com valores igual a "0,00" r...
# 1996              2. Células com "-" (traço) represe...
#
#                                        food_description cooking_method_id  \
# 3                                                   NaN               NaN
# 4     Arroz (polido, parboilizado, agulha, agulhinha...                99
# 5                                        Arroz integral                99
# 6                                       Milho (em grão)                 1
# 7                                       Milho (em grão)                 2
# ...                                                 ...               ...
# 1992                                             Palma                 99
# 1993                                                NaN               NaN
# 1994                                                NaN               NaN
# 1995                                                NaN               NaN
# 1996                                                NaN               NaN
#
#      cooking_method_description energy_kcal protein_g   lipid_g  \
# 3                           NaN         NaN       NaN       NaN
# 4                 Não se aplica  135.622946  2.496113  1.200042
# 5                 Não se aplica  130.945644  2.562885  1.965797
# 6                        Cru(a)     160.141      3.32     7.178
# 7                     Cozido(a)     160.141      3.32     7.178
# ...                         ...         ...       ...       ...
# 1992              Não se aplica      41.945      1.35     3.098
# 1993                        NaN         NaN       NaN       NaN
# 1994                        NaN         NaN       NaN       NaN
# 1995                        NaN         NaN       NaN       NaN
# 1996                        NaN         NaN       NaN       NaN
#
#      carbohydrate_g   fiber_g  \
# 3               NaN       NaN
# 4         27.784863  1.545702
# 5         25.556814   2.72239
# 6             25.11      4.25
# 7             25.11      4.25
# ...             ...       ...
# 1992           3.28         2
# 1993            NaN       NaN
# 1994            NaN       NaN
# 1995            NaN       NaN
# 1996            NaN       NaN
#
#                                                category
# 3                                 Cereais e leguminosas
# 4                                 Cereais e leguminosas
# 5                                 Cereais e leguminosas
# 6                                 Cereais e leguminosas
# 7                                 Cereais e leguminosas
# ...                                                 ...
# 1992                                        Miscelâneas
# 1993                                        Miscelâneas
# 1994  Fonte: IBGE, Diretoria de Pesquisas, Coordenaç...
# 1995  Notas: 1. Células com valores igual a "0,00" r...
# 1996              2. Células com "-" (traço) represe...
#
# [1994 rows x 10 columns]

# %%
df = df.dropna(subset=['food_description'])
df
# Out:
#       food_id                                   food_description  \
# 4     6300101  Arroz (polido, parboilizado, agulha, agulhinha...
# 5     6300201                                     Arroz integral
# 6     6300701                                    Milho (em grão)
# 7     6300701                                    Milho (em grão)
# 8     6300701                                    Milho (em grão)
# ...       ...                                                ...
# 1988  8579003                                       Maria izabel
# 1989  8579004                                     Arroz de leite
# 1990  8579005                                 Arroz com mandioca
# 1991  8579006                                      Arroz com ovo
# 1992  8800109                                             Palma
#
#      cooking_method_id   cooking_method_description energy_kcal protein_g  \
# 4                   99                Não se aplica  135.622946  2.496113
# 5                   99                Não se aplica  130.945644  2.562885
# 6                    1                       Cru(a)     160.141      3.32
# 7                    2                    Cozido(a)     160.141      3.32
# 8                    3  Grelhado(a)/brasa/churrasco     160.141      3.32
# ...                ...                          ...         ...       ...
# 1988                99                Não se aplica         154      10.8
# 1989                99                Não se aplica     142.422      2.98
# 1990                99                Não se aplica  130.311473  1.548056
# 1991                99                Não se aplica  179.106973  8.085056
# 1992                99                Não se aplica      41.945      1.35
#
#        lipid_g carbohydrate_g   fiber_g               category
# 4     1.200042      27.784863  1.545702  Cereais e leguminosas
# 5     1.965797      25.556814   2.72239  Cereais e leguminosas
# 6        7.178          25.11      4.25  Cereais e leguminosas
# 7        7.178          25.11      4.25  Cereais e leguminosas
# 8        7.178          25.11      4.25  Cereais e leguminosas
# ...        ...            ...       ...                    ...
# 1988       7.1           11.6       1.5            Miscelâneas
# 1989     4.174         22.622     0.303            Miscelâneas
# 1990  0.750021      28.942432  1.572851            Miscelâneas
# 1991  9.427021      14.500932  0.772851            Miscelâneas
# 1992     3.098           3.28         2            Miscelâneas
#
# [1971 rows x 10 columns]

# %%
df[df['energy_kcal'] == '-']
# Out:
#       food_id               food_description cooking_method_id  \
# 577   6901801            Adoçante artificial                99
# 679   6914003         Adoçante liquido light                99
# 1736  8201502            Fanta laranja light                99
# 1737  8201601  Refrigerante de guaraná light                99
# 1738  8201602                  Guaraná light                99
# 1761  8207401   Refrigerante de guaraná diet                99
# 1762  8207402                   Guaraná diet                99
# 1763  8207601     Refrigerante de limão diet                99
# 1764  8207705                Fanta uva light                99
#
#      cooking_method_description energy_kcal protein_g lipid_g carbohydrate_g  \
# 577               Não se aplica           -         -       -              -
# 679               Não se aplica           -         -       -              -
# 1736              Não se aplica           -       0.1       -              -
# 1737              Não se aplica           -         -       -              -
# 1738              Não se aplica           -         -       -              -
# 1761              Não se aplica           -         -       -              -
# 1762              Não se aplica           -         -       -              -
# 1763              Não se aplica           -       0.1       -              -
# 1764              Não se aplica           -       0.1       -              -
#
#      fiber_g                             category
# 577        -  Açúcares e produtos de confeitaria
# 679        -  Açúcares e produtos de confeitaria
# 1736       -    Bebidas não alcoólicas e infusões
# 1737       -    Bebidas não alcoólicas e infusões
# 1738       -    Bebidas não alcoólicas e infusões
# 1761       -    Bebidas não alcoólicas e infusões
# 1762       -    Bebidas não alcoólicas e infusões
# 1763       -    Bebidas não alcoólicas e infusões
# 1764       -    Bebidas não alcoólicas e infusões

# %%
df[df['protein_g'] == '-']
# Out:
#       food_id                          food_description cooking_method_id  \
# 467   6802501                            Cana-de-açúcar                99
# 537   6900302                                  Demerara                99
# 539   6900401                                  Rapadura                99
# 540   6900402                           Alfenim de cana                99
# 543   6900502  Picolé de qualquer sabor industrializado                99
# ...       ...                                       ...               ...
# 1877  8500602                         Refresco de caju                 99
# 1878  8500603                     Refresco de groselha                 99
# 1879  8500604                      Refresco de laranja                 99
# 1880  8500605                     Refresco de maracujá                 99
# 1881  8500606                         Refresco de limão                99
#
#      cooking_method_description energy_kcal protein_g lipid_g carbohydrate_g  \
# 467               Não se aplica       73.58         -    0.05          19.97
# 537               Não se aplica         387         -       -          99.98
# 539               Não se aplica         296         -       -           76.6
# 540               Não se aplica         296         -       -           76.6
# 543               Não se aplica          79         -    0.24          19.23
# ...                         ...         ...       ...     ...            ...
# 1877              Não se aplica      46.805         -       -          11.92
# 1878              Não se aplica      46.805         -       -          11.92
# 1879              Não se aplica      46.805         -       -          11.92
# 1880              Não se aplica      46.805         -       -          11.92
# 1881              Não se aplica      46.805         -       -          11.92
#
#      fiber_g                             category
# 467        -                               Frutas
# 537        -  Açúcares e produtos de confeitaria
# 539        -  Açúcares e produtos de confeitaria
# 540        -  Açúcares e produtos de confeitaria
# 543        -  Açúcares e produtos de confeitaria
# ...      ...                                  ...
# 1877   0.199                          Miscelâneas
# 1878   0.199                          Miscelâneas
# 1879   0.199                          Miscelâneas
# 1880   0.199                          Miscelâneas
# 1881   0.199                          Miscelâneas
#
# [73 rows x 10 columns]

# %%
df[df['lipid_g'] == '-']
# Out:
#       food_id       food_description cooking_method_id  \
# 173   6501502       Goma de mandioca                99
# 178   6501516        Tapioca de goma                99
# 180   6502101                 Neston                99
# 495   6804601             Cajá-manga                99
# 498   6804702       Acaja (taberebá)                99
# ...       ...                    ...               ...
# 1879  8500604   Refresco de laranja                 99
# 1880  8500605  Refresco de maracujá                 99
# 1881  8500606      Refresco de limão                99
# 1917  8503202        Caldo de carne                 99
# 1919  8503204       Caldo de mocotó                 99
#
#      cooking_method_description energy_kcal protein_g lipid_g carbohydrate_g  \
# 173               Não se aplica         336         2       -             82
# 178               Não se aplica         336         2       -             82
# 180               Não se aplica       345.8     12.92       -           70.8
# 495               Não se aplica          46       1.3       -           11.4
# 498               Não se aplica          46       1.3       -           11.4
# ...                         ...         ...       ...     ...            ...
# 1879              Não se aplica      46.805         -       -          11.92
# 1880              Não se aplica      46.805         -       -          11.92
# 1881              Não se aplica      46.805         -       -          11.92
# 1917              Não se aplica        7.02     1.361       -          0.454
# 1919              Não se aplica        7.02     1.361       -          0.454
#
#      fiber_g                    category
# 173        -  Farinhas, féculas e massas
# 178        -  Farinhas, féculas e massas
# 180     6.25  Farinhas, féculas e massas
# 495      2.6                      Frutas
# 498      2.6                      Frutas
# ...      ...                         ...
# 1879   0.199                 Miscelâneas
# 1880   0.199                 Miscelâneas
# 1881   0.199                 Miscelâneas
# 1917       -                 Miscelâneas
# 1919       -                 Miscelâneas
#
# [87 rows x 10 columns]

# %%
df[df['carbohydrate_g'] == '-']
# Out:
#       food_id        food_description cooking_method_id  \
# 577   6901801     Adoçante artificial                99
# 679   6914003  Adoçante liquido light                99
# 705   7100101             Filé-mignon                 2
# 706   7100101             Filé-mignon                 3
# 707   7100101             Filé-mignon                 4
# ...       ...                     ...               ...
# 1810  8403501           Óleo de dendê                99
# 1819  8500210               Torresmo                 99
# 1897  8501004                 Galeto                 99
# 1898  8501104                 Costela                99
# 1921  8503801               Churrasco                99
#
#        cooking_method_description energy_kcal protein_g lipid_g  \
# 577                 Não se aplica           -         -       -
# 679                 Não se aplica           -         -       -
# 705                     Cozido(a)         204     30.67       9
# 706   Grelhado(a)/brasa/churrasco         204     30.67       9
# 707                     Assado(a)         204     30.67       9
# ...                           ...         ...       ...     ...
# 1810                Não se aplica      857.84         -  99.517
# 1819                Não se aplica         544      61.3    31.3
# 1897                Não se aplica     261.659      27.3  16.163
# 1898                Não se aplica         365      22.6   29.79
# 1921                Não se aplica         204     30.67       9
#
#      carbohydrate_g fiber_g                             category
# 577               -       -  Açúcares e produtos de confeitaria
# 679               -       -  Açúcares e produtos de confeitaria
# 705               -       -                    Carnes e vísceras
# 706               -       -                    Carnes e vísceras
# 707               -       -                    Carnes e vísceras
# ...             ...     ...                                  ...
# 1810              -       -                     Óleos e gorduras
# 1819              -       -                          Miscelâneas
# 1897              -       -                          Miscelâneas
# 1898              -       -                          Miscelâneas
# 1921              -       -                          Miscelâneas
#
# [573 rows x 10 columns]

# %%
df[df['fiber_g'] == '-']
# Out:
#       food_id                         food_description cooking_method_id  \
# 173   6501502                         Goma de mandioca                99
# 178   6501516                          Tapioca de goma                99
# 216   6505101                                 Sustagem                99
# 219   6505701  Complemento alimentar de qualquer sabor                99
# 244   6601902                                   Bacaba                99
# ...       ...                                      ...               ...
# 1917  8503202                          Caldo de carne                 99
# 1919  8503204                         Caldo de mocotó                 99
# 1921  8503801                                Churrasco                99
# 1938  8506501                                 Omelete                 99
# 1950  8507701                                  Gemada                 99
#
#      cooking_method_description energy_kcal protein_g lipid_g carbohydrate_g  \
# 173               Não se aplica         336         2       -             82
# 178               Não se aplica         336         2       -             82
# 216               Não se aplica     369.152     24.05   0.493         68.017
# 219               Não se aplica     369.152     24.05   0.493         68.017
# 244               Não se aplica         212      3.12    19.8            6.6
# ...                         ...         ...       ...     ...            ...
# 1917              Não se aplica        7.02     1.361       -          0.454
# 1919              Não se aplica        7.02     1.361       -          0.454
# 1921              Não se aplica         204     30.67       9              -
# 1938              Não se aplica     241.618    11.035  21.259          0.982
# 1950              Não se aplica     134.794     3.804   7.469         13.519
#
#      fiber_g                    category
# 173        -  Farinhas, féculas e massas
# 178        -  Farinhas, féculas e massas
# 216        -  Farinhas, féculas e massas
# 219        -  Farinhas, féculas e massas
# 244        -    Cocos, castanhas e nozes
# ...      ...                         ...
# 1917       -                 Miscelâneas
# 1919       -                 Miscelâneas
# 1921       -                 Miscelâneas
# 1938       -                 Miscelâneas
# 1950       -                 Miscelâneas
#
# [858 rows x 10 columns]

# %%
df['energy_kcal'] = df['energy_kcal'].replace('-', 0)
df['protein_g'] = df['protein_g'].replace('-', 0)
df['lipid_g'] = df['lipid_g'].replace('-', 0)
df['carbohydrate_g'] = df['carbohydrate_g'].replace('-', 0)
df['fiber_g'] = df['fiber_g'].replace('-', 0)
# Out:
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_15428\598866594.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['energy_kcal'] = df['energy_kcal'].replace('-', 0)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_15428\598866594.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['energy_kcal'] = df['energy_kcal'].replace('-', 0)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_15428\598866594.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['protein_g'] = df['protein_g'].replace('-', 0)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_15428\598866594.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['protein_g'] = df['protein_g'].replace('-', 0)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_15428\598866594.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['lipid_g'] = df['lipid_g'].replace('-', 0)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_15428\598866594.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lipid_g'] = df['lipid_g'].replace('-', 0)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_15428\598866594.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['carbohydrate_g'] = df['carbohydrate_g'].replace('-', 0)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_15428\598866594.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['carbohydrate_g'] = df['carbohydrate_g'].replace('-', 0)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_15428\598866594.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['fiber_g'] = df['fiber_g'].replace('-', 0)
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_15428\598866594.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fiber_g'] = df['fiber_g'].replace('-', 0)

# %%
df['category'].unique()
# Out:
# array(['Cereais e leguminosas', 'Hortaliças tuberosas',
#        'Farinhas, féculas e massas', 'Cocos, castanhas e nozes',
#        'Hortaliças folhosas, frutosas e outras', 'Frutas',
#        'Açúcares e produtos de confeitaria ', 'Sais e condimentos',
#        'Carnes e vísceras', 'Pescados e frutos do mar',
#        'Enlatados e conservas', 'Aves e ovos  ', 'Laticínios',
#        'Panificados', 'Carnes industrializadas',
#        'Bebidas não alcoólicas e infusões', 'Bebidas alcoólicas',
#        'Óleos e gorduras', 'Miscelâneas'], dtype=object)

# %%
df.loc[:,'food_id'] = df['food_id'].astype(str)
df.loc[:,'food_description'] = df['food_description'].astype(str)
df.loc[:,'cooking_method_id'] = df['cooking_method_id'].astype(int)
df.loc[:,'cooking_method_description'] = df['cooking_method_description'].astype(str)
df.loc[:,'energy_kcal'] = df['energy_kcal'].astype(float)
df.loc[:,'protein_g'] = df['protein_g'].astype(float)
df.loc[:,'lipid_g'] = df['lipid_g'].astype(float)
df.loc[:,'carbohydrate_g'] = df['carbohydrate_g'].astype(float)
df.loc[:,'fiber_g'] = df['fiber_g'].astype(float)
df.loc[:,'category'] = df['category'].astype(str)

# %%
df
# Out:
#       food_id                                   food_description  \
# 4     6300101  Arroz (polido, parboilizado, agulha, agulhinha...
# 5     6300201                                     Arroz integral
# 6     6300701                                    Milho (em grão)
# 7     6300701                                    Milho (em grão)
# 8     6300701                                    Milho (em grão)
# ...       ...                                                ...
# 1988  8579003                                       Maria izabel
# 1989  8579004                                     Arroz de leite
# 1990  8579005                                 Arroz com mandioca
# 1991  8579006                                      Arroz com ovo
# 1992  8800109                                             Palma
#
#      cooking_method_id   cooking_method_description  energy_kcal  protein_g  \
# 4                   99                Não se aplica   135.622946   2.496113
# 5                   99                Não se aplica   130.945644   2.562885
# 6                    1                       Cru(a)   160.141000   3.320000
# 7                    2                    Cozido(a)   160.141000   3.320000
# 8                    3  Grelhado(a)/brasa/churrasco   160.141000   3.320000
# ...                ...                          ...          ...        ...
# 1988                99                Não se aplica   154.000000  10.800000
# 1989                99                Não se aplica   142.422000   2.980000
# 1990                99                Não se aplica   130.311473   1.548056
# 1991                99                Não se aplica   179.106973   8.085056
# 1992                99                Não se aplica    41.945000   1.350000
#
#        lipid_g  carbohydrate_g   fiber_g               category
# 4     1.200042       27.784863  1.545702  Cereais e leguminosas
# 5     1.965797       25.556814  2.722390  Cereais e leguminosas
# 6     7.178000       25.110000  4.250000  Cereais e leguminosas
# 7     7.178000       25.110000  4.250000  Cereais e leguminosas
# 8     7.178000       25.110000  4.250000  Cereais e leguminosas
# ...        ...             ...       ...                    ...
# 1988  7.100000       11.600000  1.500000            Miscelâneas
# 1989  4.174000       22.622000  0.303000            Miscelâneas
# 1990  0.750021       28.942432  1.572851            Miscelâneas
# 1991  9.427021       14.500932  0.772851            Miscelâneas
# 1992  3.098000        3.280000  2.000000            Miscelâneas
#
# [1971 rows x 10 columns]

# %%
df['description'] = None
df.loc[:, 'description'] = df['food_description'] + ', ' + df['cooking_method_description']
df.loc[:,'description'] = df['description'].replace(', Não se aplica', '')
# Out:
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_15428\1894930428.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['description'] = None

# %%
df
# Out:
#       food_id                                   food_description  \
# 4     6300101  Arroz (polido, parboilizado, agulha, agulhinha...
# 5     6300201                                     Arroz integral
# 6     6300701                                    Milho (em grão)
# 7     6300701                                    Milho (em grão)
# 8     6300701                                    Milho (em grão)
# ...       ...                                                ...
# 1988  8579003                                       Maria izabel
# 1989  8579004                                     Arroz de leite
# 1990  8579005                                 Arroz com mandioca
# 1991  8579006                                      Arroz com ovo
# 1992  8800109                                             Palma
#
#      cooking_method_id   cooking_method_description  energy_kcal  protein_g  \
# 4                   99                Não se aplica   135.622946   2.496113
# 5                   99                Não se aplica   130.945644   2.562885
# 6                    1                       Cru(a)   160.141000   3.320000
# 7                    2                    Cozido(a)   160.141000   3.320000
# 8                    3  Grelhado(a)/brasa/churrasco   160.141000   3.320000
# ...                ...                          ...          ...        ...
# 1988                99                Não se aplica   154.000000  10.800000
# 1989                99                Não se aplica   142.422000   2.980000
# 1990                99                Não se aplica   130.311473   1.548056
# 1991                99                Não se aplica   179.106973   8.085056
# 1992                99                Não se aplica    41.945000   1.350000
#
#        lipid_g  carbohydrate_g   fiber_g               category  \
# 4     1.200042       27.784863  1.545702  Cereais e leguminosas
# 5     1.965797       25.556814  2.722390  Cereais e leguminosas
# 6     7.178000       25.110000  4.250000  Cereais e leguminosas
# 7     7.178000       25.110000  4.250000  Cereais e leguminosas
# 8     7.178000       25.110000  4.250000  Cereais e leguminosas
# ...        ...             ...       ...                    ...
# 1988  7.100000       11.600000  1.500000            Miscelâneas
# 1989  4.174000       22.622000  0.303000            Miscelâneas
# 1990  0.750021       28.942432  1.572851            Miscelâneas
# 1991  9.427021       14.500932  0.772851            Miscelâneas
# 1992  3.098000        3.280000  2.000000            Miscelâneas
#
#                                             description
# 4     Arroz (polido, parboilizado, agulha, agulhinha...
# 5                         Arroz integral, Não se aplica
# 6                               Milho (em grão), Cru(a)
# 7                            Milho (em grão), Cozido(a)
# 8          Milho (em grão), Grelhado(a)/brasa/churrasco
# ...                                                 ...
# 1988                        Maria izabel, Não se aplica
# 1989                      Arroz de leite, Não se aplica
# 1990                  Arroz com mandioca, Não se aplica
# 1991                       Arroz com ovo, Não se aplica
# 1992                              Palma , Não se aplica
#
# [1971 rows x 11 columns]

# %%
df.loc[:,'description'] = df['description'].replace(', Não se aplica', '', regex=True)
df.reset_index(inplace=True)
df['id'] = df.index.to_list()
# Out:
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_15428\2928927938.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['id'] = df.index.to_list()

# %%
import re 

def split_description(text):
    detail = None
    match = re.search(pattern=r"\(.{3,}?\)", string=text)
    
    if match:
        detail = match.group(0)
        text = text.replace(detail, '').strip()
        detail = detail.replace('(', '').replace(')', '').strip()

    text_splitted = [x.strip() for x in text.split(',')]
    if detail != None:
        text_splitted.append(detail)
    return text_splitted

# %%
df['splitted'] = df['description'].apply(split_description)
df
# Out:
# C:\Users\marilia.fernandez\AppData\Local\Temp\ipykernel_15428\2757727958.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['splitted'] = df['description'].apply(split_description)
#       index  food_id                                   food_description  \
# 0         4  6300101  Arroz (polido, parboilizado, agulha, agulhinha...
# 1         5  6300201                                     Arroz integral
# 2         6  6300701                                    Milho (em grão)
# 3         7  6300701                                    Milho (em grão)
# 4         8  6300701                                    Milho (em grão)
# ...     ...      ...                                                ...
# 1966   1988  8579003                                       Maria izabel
# 1967   1989  8579004                                     Arroz de leite
# 1968   1990  8579005                                 Arroz com mandioca
# 1969   1991  8579006                                      Arroz com ovo
# 1970   1992  8800109                                             Palma
#
#      cooking_method_id   cooking_method_description  energy_kcal  protein_g  \
# 0                   99                Não se aplica   135.622946   2.496113
# 1                   99                Não se aplica   130.945644   2.562885
# 2                    1                       Cru(a)   160.141000   3.320000
# 3                    2                    Cozido(a)   160.141000   3.320000
# 4                    3  Grelhado(a)/brasa/churrasco   160.141000   3.320000
# ...                ...                          ...          ...        ...
# 1966                99                Não se aplica   154.000000  10.800000
# 1967                99                Não se aplica   142.422000   2.980000
# 1968                99                Não se aplica   130.311473   1.548056
# 1969                99                Não se aplica   179.106973   8.085056
# 1970                99                Não se aplica    41.945000   1.350000
#
#        lipid_g  carbohydrate_g   fiber_g               category  \
# 0     1.200042       27.784863  1.545702  Cereais e leguminosas
# 1     1.965797       25.556814  2.722390  Cereais e leguminosas
# 2     7.178000       25.110000  4.250000  Cereais e leguminosas
# 3     7.178000       25.110000  4.250000  Cereais e leguminosas
# 4     7.178000       25.110000  4.250000  Cereais e leguminosas
# ...        ...             ...       ...                    ...
# 1966  7.100000       11.600000  1.500000            Miscelâneas
# 1967  4.174000       22.622000  0.303000            Miscelâneas
# 1968  0.750021       28.942432  1.572851            Miscelâneas
# 1969  9.427021       14.500932  0.772851            Miscelâneas
# 1970  3.098000        3.280000  2.000000            Miscelâneas
#
#                                             description    id  \
# 0     Arroz (polido, parboilizado, agulha, agulhinha...     0
# 1                                        Arroz integral     1
# 2                               Milho (em grão), Cru(a)     2
# 3                            Milho (em grão), Cozido(a)     3
# 4          Milho (em grão), Grelhado(a)/brasa/churrasco     4
# ...                                                 ...   ...
# 1966                                       Maria izabel  1966
# 1967                                     Arroz de leite  1967
# 1968                                 Arroz com mandioca  1968
# 1969                                      Arroz com ovo  1969
# 1970                                             Palma   1970
#
#                                                splitted
# 0     [Arroz, polido, parboilizado, agulha, agulhinh...
# 1                                      [Arroz integral]
# 2                              [Milho, Cru(a), em grão]
# 3                           [Milho, Cozido(a), em grão]
# 4         [Milho, Grelhado(a)/brasa/churrasco, em grão]
# ...                                                 ...
# 1966                                     [Maria izabel]
# 1967                                   [Arroz de leite]
# 1968                               [Arroz com mandioca]
# 1969                                    [Arroz com ovo]
# 1970                                            [Palma]
#
# [1971 rows x 14 columns]

# %%
columns = ['id', 'description', 'category', 'splitted', 'energy_kcal', 'protein_g', 'lipid_g', 'carbohydrate_g', 'fiber_g']
df[columns]
# Out:
#         id                                        description  \
# 0        0  Arroz (polido, parboilizado, agulha, agulhinha...
# 1        1                                     Arroz integral
# 2        2                            Milho (em grão), Cru(a)
# 3        3                         Milho (em grão), Cozido(a)
# 4        4       Milho (em grão), Grelhado(a)/brasa/churrasco
# ...    ...                                                ...
# 1966  1966                                       Maria izabel
# 1967  1967                                     Arroz de leite
# 1968  1968                                 Arroz com mandioca
# 1969  1969                                      Arroz com ovo
# 1970  1970                                             Palma
#
#                    category  \
# 0     Cereais e leguminosas
# 1     Cereais e leguminosas
# 2     Cereais e leguminosas
# 3     Cereais e leguminosas
# 4     Cereais e leguminosas
# ...                     ...
# 1966            Miscelâneas
# 1967            Miscelâneas
# 1968            Miscelâneas
# 1969            Miscelâneas
# 1970            Miscelâneas
#
#                                                splitted  energy_kcal  \
# 0     [Arroz, polido, parboilizado, agulha, agulhinh...   135.622946
# 1                                      [Arroz integral]   130.945644
# 2                              [Milho, Cru(a), em grão]   160.141000
# 3                           [Milho, Cozido(a), em grão]   160.141000
# 4         [Milho, Grelhado(a)/brasa/churrasco, em grão]   160.141000
# ...                                                 ...          ...
# 1966                                     [Maria izabel]   154.000000
# 1967                                   [Arroz de leite]   142.422000
# 1968                               [Arroz com mandioca]   130.311473
# 1969                                    [Arroz com ovo]   179.106973
# 1970                                            [Palma]    41.945000
#
#       protein_g   lipid_g  carbohydrate_g   fiber_g
# 0      2.496113  1.200042       27.784863  1.545702
# 1      2.562885  1.965797       25.556814  2.722390
# 2      3.320000  7.178000       25.110000  4.250000
# 3      3.320000  7.178000       25.110000  4.250000
# 4      3.320000  7.178000       25.110000  4.250000
# ...         ...       ...             ...       ...
# 1966  10.800000  7.100000       11.600000  1.500000
# 1967   2.980000  4.174000       22.622000  0.303000
# 1968   1.548056  0.750021       28.942432  1.572851
# 1969   8.085056  9.427021       14.500932  0.772851
# 1970   1.350000  3.098000        3.280000  2.000000
#
# [1971 rows x 9 columns]

# %%
df[columns].to_json('ibge.json', orient='records', indent=4, force_ascii=False)
